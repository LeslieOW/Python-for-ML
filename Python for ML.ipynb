# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load data
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin-1")

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# 3     94.35     94.72     92.82     91.83
# 4     79.36     77.40     80.19     77.28

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
#check for duplicates
sum(df.duplicated())
# Out:
# 0

# %%
#check for missing values
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#drop missing values
df = df.dropna()

# %%
#confirm there are no missing values
df.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
df.shape
# Out:
# (57784, 12)

# %%
#obtain summary statistics
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  57784.000000  57784.000000  57784.000000   57784.000000   57784.000000
# mean     134.499342   2690.495656   3745.422868     137.831770     138.990488
# std       72.651212    146.625825   2217.914615    1588.660769    1625.441821
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2563.000000    674.000000       0.000000       0.000000
# 50%      136.000000   2633.000000   5142.000000       0.140000       0.130000
# 75%      196.000000   2781.000000   5301.000000       9.000000       9.000000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   57784.000000   57784.000000   57784.000000
# mean      140.376380     144.927790     148.027664
# std      1662.732983    1695.436448    1735.920219
# min     -3225.000000   -1582.000000   -3396.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.130000       0.160000       0.130000
# 75%         9.000000      10.000000      10.000000
# max    185960.000000  190873.000000  195875.000000

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005850      0.003624  0.006091  0.005267
# Item Code     -0.005850   1.000000     -0.016521  0.021102  0.020226
# Element Code   0.003624  -0.016521      1.000000  0.026257  0.025632
# Y2014          0.006091   0.021102      0.026257  1.000000  0.994647
# Y2015          0.005267   0.020226      0.025632  0.994647  1.000000
# Y2016          0.005246   0.019382      0.025080  0.996081  0.995738
# Y2017          0.004979   0.020812      0.025932  0.995229  0.988047
# Y2018          0.005571   0.020527      0.025989  0.994871  0.988207
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005246  0.004979  0.005571
# Item Code     0.019382  0.020812  0.020527
# Element Code  0.025080  0.025932  0.025989
# Y2014         0.996081  0.995229  0.994871
# Y2015         0.995738  0.988047  0.988207
# Y2016         1.000000  0.992784  0.992756
# Y2017         0.992784  1.000000  0.998103
# Y2018         0.992756  0.998103  1.000000

# %%
df['Area'].nunique()
# Out:
# 49

# %%
gb = df.groupby('Area')
gb

# %%
ga = df.groupby('Area')

# %%
ga

# %%
ga['Y2017', 'Area']
# Out:
# C:\Users\visitor acc\AppData\Local\Temp\ipykernel_76512\2102314687.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ga['Y2017', 'Area']

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]

# %%
x
# Out:
# 8

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array
# Out:
# [[94, 89, 63], [93, 92, 48], [92, 94, 56]]

# %%
#array[:1,1:]

# %%
df1.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df1.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.080000       0.100000       0.070000
# 75%         8.430000       9.000000       9.000000
# max    185960.000000  190873.000000  195875.000000

# %%
#df1.loc(:)

# %%
df1.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# 1                    Domestic supply quantity      1000 tonnes      0.00
# 2               Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3      Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4          Fat supply quantity (g/capita/day)     g/capita/day     80.06
# ...                                       ...              ...       ...
# 60938                                    Food      1000 tonnes     42.00
# 60939     Food supply quantity (kg/capita/yr)               kg      3.06
# 60940           Food supply (kcal/capita/day)  kcal/capita/day      3.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day      0.10
# 60942      Fat supply quantity (g/capita/day)     g/capita/day      0.04
#
#           Y2015     Y2016     Y2017     Y2018
# 0      39728.00  40551.00  41389.00  42228.00
# 1          0.00      0.00      0.00      0.00
# 2       3379.00   3372.00   3341.00   3322.00
# 3         94.35     94.72     92.82     91.83
# 4         79.36     77.40     80.19     77.28
# ...         ...       ...       ...       ...
# 60938     46.00     33.00     19.00     16.00
# 60939      3.33      2.35      1.33      1.08
# 60940      4.00      3.00      1.00      1.00
# 60941      0.11      0.08      0.04      0.04
# 60942      0.05      0.03      0.02      0.01
#
# [60943 rows x 12 columns]

# %%
df1.loc

# %%
#df1.groupby('Element').df1['Y2017'].sum()

# %%
df1.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# Name: Y2017, dtype: float64

# %%
df1.groupby('Area')['Area', 'Y2017'].sum().sort_index(ascending=True)
# Out:
# C:\Users\visitor acc\AppData\Local\Temp\ipykernel_76512\1422276275.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby('Area')['Area', 'Y2017'].sum().sort_index(ascending=True)
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# Kenya                         264660.66
# Lesotho                        21267.96
# Liberia                        29342.20
# Madagascar                    131197.73
# Malawi                        181098.71
# Mali                          149928.33
# Mauritania                    156665.46
# Mauritius                      51114.83
# Morocco                       388495.36
# Mozambique                    161407.98
# Namibia                        29874.89
# Niger                         126707.58
# Nigeria                      1483268.23
# Rwanda                         73663.69
# Sao Tome and Principe          12662.63
# Senegal                        95681.15
# Seychelles                       442.34
# Sierra Leone                   55311.33
# South Africa                  517590.54
# Sudan                         239931.92
# Sudan (former)                     0.00
# Togo                           49841.88
# Tunisia                       124167.20
# Uganda                        213950.38
# United Republic of Tanzania   322616.85
# Zambia                        103223.77
# Zimbabwe                       75919.34

# %%
df1.groupby('Item')['Y2015', 'Y2018'].sum()
# Out:
# C:\Users\visitor acc\AppData\Local\Temp\ipykernel_76512\4255234817.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby('Item')['Y2015', 'Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
df1.groupby('Area')['Y2017' , 'Area'].sum()
# Out:
# C:\Users\visitor acc\AppData\Local\Temp\ipykernel_76512\2700126785.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby('Area')['Y2017' , 'Area'].sum()
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# Kenya                         264660.66
# Lesotho                        21267.96
# Liberia                        29342.20
# Madagascar                    131197.73
# Malawi                        181098.71
# Mali                          149928.33
# Mauritania                    156665.46
# Mauritius                      51114.83
# Morocco                       388495.36
# Mozambique                    161407.98
# Namibia                        29874.89
# Niger                         126707.58
# Nigeria                      1483268.23
# Rwanda                         73663.69
# Sao Tome and Principe          12662.63
# Senegal                        95681.15
# Seychelles                       442.34
# Sierra Leone                   55311.33
# South Africa                  517590.54
# Sudan                         239931.92
# Sudan (former)                     0.00
# Togo                           49841.88
# Tunisia                       124167.20
# Uganda                        213950.38
# United Republic of Tanzania   322616.85
# Zambia                        103223.77
# Zimbabwe                       75919.34
